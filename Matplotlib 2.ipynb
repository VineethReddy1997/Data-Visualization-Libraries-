# %% [markdown]
# # Matplotlib

# %% [raw]
# Matplotlib is a library in python  (visualization tool)
# It is used genelly purposed showing the data information as simple  plots
# Generally easy to get started for simple plots
# support for custom labels and texts
# great quality of every elements in a figure
# High quality output in many formats
# very customizable

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#simple example 
x = np.arange(0,10)
y = np.arange(11,21)

# %%
#scatter plot using matplotlib

plt.scatter(x,y, c = 'r',s )    #scatter x,y and c is colour
plt.xlabel=('X axis')
plt.ylabel=('y axis')
plt.title('graph in 2d ')
# Out:
# Text(0.5, 1.0, 'graph in 2d ')

# %%
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
# make the data
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))
# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=100, c=colors, vmin=10, vmax=100)

ax.set(xlim=(0, 8), xticks=np.arange(1, 10),
       ylim=(0, 8), yticks=np.arange(1, 10))

plt.show()
